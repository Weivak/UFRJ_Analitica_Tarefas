# %%
import basedosdados as bd
bd.config.billing_project_id =  'ufrj-analitica-selecao'

query = """
SELECT * FROM `basedosdados.eu_fra_lgbt.violencia_abuso` LIMIT 100
"""

df = bd.read_sql(query=query)
# Out:
# Downloading: 100%|██████████| 100/100 [00:00<00:00, 276.74rows/s]

# %%
bd.list_dataset_tables('eu_fra_lgbt', with_description=False, verbose=True)
# Out:
# table_id:
# 	especifico_transgenero
# -----------------------------------------------------------------------------------------------
# table_id:
# 	cotidiano
# -----------------------------------------------------------------------------------------------
# table_id:
# 	discriminacao
# -----------------------------------------------------------------------------------------------
# table_id:
# 	consciencia_direitos
# -----------------------------------------------------------------------------------------------
# table_id:
# 	violencia_abuso
# -----------------------------------------------------------------------------------------------

# %%
df
# Out:
#        pais_ingles         grupo id_pergunta  \
# 0          Austria       Lesbian          e1
# 1          Austria       Lesbian          e1
# 2          Austria       Lesbian          e1
# 3          Austria       Lesbian          e1
# 4          Austria           Gay          e1
# ..             ...           ...         ...
# 95  Czech Republic  Bisexual men          e1
# 96  Czech Republic   Transgender          e1
# 97  Czech Republic   Transgender          e1
# 98  Czech Republic   Transgender          e1
# 99  Czech Republic   Transgender          e1
#
#                                              pergunta  \
# 0   Do you avoid holding hands in public with a sa...
# 1   Do you avoid holding hands in public with a sa...
# 2   Do you avoid holding hands in public with a sa...
# 3   Do you avoid holding hands in public with a sa...
# 4   Do you avoid holding hands in public with a sa...
# ..                                                ...
# ...

# %%
query = """
SELECT * FROM `basedosdados.eu_fra_lgbt.discriminacao` LIMIT 100
"""

df_discriminacao = bd.read_sql(query=query)
# Out:
# Downloading: 100%|██████████| 100/100 [00:00<00:00, 295.69rows/s]

# %%
df_discriminacao
# Out:
#    pais_ingles    grupo id_pergunta  \
# 0      Austria  Lesbian         c10
# 1      Austria  Lesbian         c10
# 2      Austria  Lesbian         c10
# 3      Austria  Lesbian         c10
# 4      Austria  Lesbian         c10
# ..         ...      ...         ...
# 95    Bulgaria  Lesbian         c10
# 96    Bulgaria  Lesbian         c10
# 97    Bulgaria      Gay         c10
# 98    Bulgaria      Gay         c10
# 99    Bulgaria      Gay         c10
#
#                                              pergunta  \
# 0   Have you ever experienced any of the following...
# 1   Have you ever experienced any of the following...
# 2   Have you ever experienced any of the following...
# 3   Have you ever experienced any of the following...
# 4   Have you ever experienced any of the following...
# ..                                                ...
# 95  Have you ever experienced any of the following...
# 96  Have you ever experienced any of the following...
# ...
